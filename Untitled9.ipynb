# %%
import statistics
import math
import numpy as np
from scipy import stats

# %%
data_set1=np.array([1,3,5,7,9])
data_set2=np.array([2,4,8,10,12])
sum=np.sum(data_set1)
print(sum)
# Out:
# 25

# %%
dat=np.random.randn(1000)
Min=np.min(dat)
Max=np.max(dat)
Sum=np.sum(dat)
Product=np.prod(dat)
print(Min,Max,Sum,Product,sep=" ")
# Out:
# -3.1500507413833922 3.6423613878032377 -6.568828283580558 7.503804343886033e-245

# %%
skewness=stats.skew(dat)
kurtosis=stats.kurtosis(dat)
print(skewness,kurtosis,sep=" ")
# Out:
# -0.00569358154616455 0.08207905919404235

# %%
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score,classification_report
import matplotlib.pyplot as plt

# %%
iris=load_iris()
X=iris.data
y=iris.target

# %%
iris_df=pd.DataFrame(X,columns=iris.feature_names)
iris_df['Target']=y
pd.plotting.scatter_matrix(iris_df,c=iris_df['Target'],figsize=(10,10),marker='*',hist_kwds={'bins':10},alpha=0.5)
plt.suptitle("Scatter Matrix of Iris Dataset",size=16)
plt.show()

# %%
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   Target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB

# %%
iris_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
# @title sepal length (cm) vs sepal width (cm)

from matplotlib import pyplot as plt
iris_df.plot(kind='scatter', x='sepal length (cm)', y='sepal width (cm)', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
iris_df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      Target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['sepal length (cm)'].plot(kind='hist', bins=20, title='sepal length (cm)')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
iris_df.describe()
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)      Target
# count        150.000000  150.000000
# mean           1.199333    1.000000
# std            0.762238    0.819232
# min            0.100000    0.000000
# 25%            0.300000    0.000000
# 50%            1.300000    1.000000
# 75%            1.800000    2.000000
# max            2.500000    2.000000

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.5,random_state=42)

# %%
X_train
# Out:
# array([[5.4, 3. , 4.5, 1.5],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.5, 2.3, 4. , 1.3],
#        [5.4, 3.9, 1.7, 0.4],
#        [5. , 2.3, 3.3, 1. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [5. , 3.3, 1.4, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 2.4, 3.8, 1.1],
#        [6.7, 3. , 5. , 1.7],
#        [4.9, 3.1, 1.5, 0.2],
#        [5.8, 2.8, 5.1, 2.4],
#        [5. , 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.9, 3.2, 4.8, 1.8],
#        [5.1, 2.5, 3. , 1.1],
#        [6.9, 3.2, 5.7, 2.3],
#        [6. , 2.7, 5.1, 1.6],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [5.5, 2.5, 4. , 1.3],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.3, 3. , 1.1, 0.1],
#        [6. , 2.2, 5. , 1.5],
#        [7.2, 3.2, 6. , 1.8],
#        [4.6, 3.1, 1.5, 0.2],
#        [5.1, 3.5, 1.4, 0.3],
#        [4.4, 3. , 1.3, 0.2],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.3, 3.4, 5.6, 2.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [6.8, 3. , 5.5, 2.1],
# ...

# %%
y_train
# Out:
# array([1, 2, 1, 0, 1, 2, 0, 0, 1, 1, 0, 2, 0, 0, 1, 1, 2, 1, 2, 2, 1, 0,
#        0, 2, 2, 0, 0, 0, 1, 2, 0, 2, 2, 0, 1, 1, 2, 1, 2, 0, 2, 1, 2, 1,
#        1, 1, 0, 1, 1, 0, 1, 2, 2, 0, 1, 2, 2, 0, 2, 0, 1, 2, 2, 1, 2, 1,
#        1, 2, 2, 0, 1, 2, 0, 1, 2])

# %%
nb_model=GaussianNB()

# %%
nb_model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=nb_model.predict(X_test)

# %%
accuracy=accuracy_score(y_test,y_pred)
print("Accuracy:",accuracy)
# Out:
# Accuracy: 0.9866666666666667

# %%
print("Classification Report:")
print(classification_report(y_test,y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        29
#            1       0.96      1.00      0.98        23
#            2       1.00      0.96      0.98        23
#
#     accuracy                           0.99        75
#    macro avg       0.99      0.99      0.99        75
# weighted avg       0.99      0.99      0.99        75
